# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
search = input("Enter model to search: ")
url = f"https://ollama.com/search?q={search}"
# Out:
# Enter model to search: gemma4

# %%
page = requests.get(url)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')
# print(soup)

# %%
search_results = soup.find_all('span',attrs={'x-test-search-response-title':True})
print(len(search_results))

links = soup.find_all('a',attrs={'class':"group w-full",'href':True})

model_links = []

for link in links:
    print(link['href'])
    model_links.append(f"https://ollama.com{link['href']}")

model_names = []
for result in search_results:
    print(result.text)
    model_names.append(result.text)
# Out:
# 20
# /library/gemma4
# /library/medgemma1.5
# /pierreprudh/gemma4-12b-mtp
# /MobiusDevelopment/gemma4-E2B-it-qat-Q4-unsloth-heretic
# /dommage/gemma4-e4b-qat
# /HanifAR24/gemma4-e2b-distilled
# /sushicodechef/gemma4
# /jeffgreen311/Eve-Gemma4-S0LF0RG3-Oracle
# /jeremihugede/gemma4-pde
# /kylin20200921/gemma4
# /GamingCat9439/Technoblade-AI
# /sonct988/gemma4-26b-a4b-it-q4km-256k
# /maxwellb/gemma4-12b-it-oym
# /batiai/gemma4-12b
# /rafw007/gemma4-e4b-claude-coder
# /Librellama/gemma4
# /SetneufPT/Gemma4-12B-IT-QAT_Q4_64K_16GB-GPU
# /mannix/gemma4-98e-v7-coder
# /SetneufPT/Gemma4-12B_Q4_64K_16GB-GPU
# /rafw007/gemma4-26b-claude-coder
# gemma4
# medgemma1.5
# pierreprudh/gemma4-12b-mtp
# MobiusDevelopment/gemma4-E2B-it-qat-Q4-unsloth-heretic
# dommage/gemma4-e4b-qat
# HanifAR24/gemma4-e2b-distilled
# sushicodechef/gemma4
# jeffgreen311/Eve-Gemma4-S0LF0RG3-Oracle
# jeremihugede/gemma4-pde
# kylin20200921/gemma4
# GamingCat9439/Technoblade-AI
# sonct988/gemma4-26b-a4b-it-q4km-256k
# maxwellb/gemma4-12b-it-oym
# batiai/gemma4-12b
# rafw007/gemma4-e4b-claude-coder
# Librellama/gemma4
# SetneufPT/Gemma4-12B-IT-QAT_Q4_64K_16GB-GPU
# mannix/gemma4-98e-v7-coder
# SetneufPT/Gemma4-12B_Q4_64K_16GB-GPU
# rafw007/gemma4-26b-claude-coder

# %%
print(model_names)
print(model_links)
# Out:
# ['gemma4', 'medgemma1.5', 'pierreprudh/gemma4-12b-mtp', 'MobiusDevelopment/gemma4-E2B-it-qat-Q4-unsloth-heretic', 'dommage/gemma4-e4b-qat', 'HanifAR24/gemma4-e2b-distilled', 'sushicodechef/gemma4', 'jeffgreen311/Eve-Gemma4-S0LF0RG3-Oracle', 'jeremihugede/gemma4-pde', 'kylin20200921/gemma4', 'GamingCat9439/Technoblade-AI', 'sonct988/gemma4-26b-a4b-it-q4km-256k', 'maxwellb/gemma4-12b-it-oym', 'batiai/gemma4-12b', 'rafw007/gemma4-e4b-claude-coder', 'Librellama/gemma4', 'SetneufPT/Gemma4-12B-IT-QAT_Q4_64K_16GB-GPU', 'mannix/gemma4-98e-v7-coder', 'SetneufPT/Gemma4-12B_Q4_64K_16GB-GPU', 'rafw007/gemma4-26b-claude-coder']
# ['https://ollama.com/library/gemma4', 'https://ollama.com/library/medgemma1.5', 'https://ollama.com/pierreprudh/gemma4-12b-mtp', 'https://ollama.com/MobiusDevelopment/gemma4-E2B-it-qat-Q4-unsloth-heretic', 'https://ollama.com/dommage/gemma4-e4b-qat', 'https://ollama.com/HanifAR24/gemma4-e2b-distilled', 'https://ollama.com/sushicodechef/gemma4', 'https://ollama.com/jeffgreen311/Eve-Gemma4-S0LF0RG3-Oracle', 'https://ollama.com/jeremihugede/gemma4-pde', 'https://ollama.com/kylin20200921/gemma4', 'https://ollama.com/GamingCat9439/Technoblade-AI', 'https://ollama.com/sonct988/gemma4-26b-a4b-it-q4km-256k', 'https://ollama.com/maxwellb/gemma4-12b-it-oym', 'https://ollama.com/batiai/gemma4-12b', 'https://ollama.com/rafw007/gemma4-e4b-claude-coder', 'https://ollama.com/Librellama/gemma4', 'https://ollama.com/SetneufPT/Gemma4-12B-IT-QAT_Q4_64K_16GB-GPU', 'https://ollama.com/mannix/gemma4-98e-v7-coder', 'https://ollama.com/SetneufPT/Gemma4-12B_Q4_64K_16GB-GPU', 'https://ollama.com/rafw007/gemma4-26b-claude-coder']

# %%
df = pd.DataFrame({'Model':model_names,'Link':model_links})
print(df)
# Out:
#                                                 Model  \
# 0                                              gemma4
# 1                                         medgemma1.5
# 2                          pierreprudh/gemma4-12b-mtp
# 3   MobiusDevelopment/gemma4-E2B-it-qat-Q4-unsloth...
# 4                              dommage/gemma4-e4b-qat
# 5                      HanifAR24/gemma4-e2b-distilled
# 6                                sushicodechef/gemma4
# 7             jeffgreen311/Eve-Gemma4-S0LF0RG3-Oracle
# 8                             jeremihugede/gemma4-pde
# 9                                kylin20200921/gemma4
# 10                       GamingCat9439/Technoblade-AI
# 11               sonct988/gemma4-26b-a4b-it-q4km-256k
# 12                         maxwellb/gemma4-12b-it-oym
# 13                                  batiai/gemma4-12b
# 14                    rafw007/gemma4-e4b-claude-coder
# 15                                  Librellama/gemma4
# 16        SetneufPT/Gemma4-12B-IT-QAT_Q4_64K_16GB-GPU
# 17                         mannix/gemma4-98e-v7-coder
# 18               SetneufPT/Gemma4-12B_Q4_64K_16GB-GPU
# 19                    rafw007/gemma4-26b-claude-coder
#
#                                                  Link
# 0                   https://ollama.com/library/gemma4
# 1              https://ollama.com/library/medgemma1.5
# 2       https://ollama.com/pierreprudh/gemma4-12b-mtp
# 3   https://ollama.com/MobiusDevelopment/gemma4-E2...
# 4           https://ollama.com/dommage/gemma4-e4b-qat
# 5   https://ollama.com/HanifAR24/gemma4-e2b-distilled
# 6             https://ollama.com/sushicodechef/gemma4
# 7   https://ollama.com/jeffgreen311/Eve-Gemma4-S0L...
# 8          https://ollama.com/jeremihugede/gemma4-pde
# 9             https://ollama.com/kylin20200921/gemma4
# 10    https://ollama.com/GamingCat9439/Technoblade-AI
# 11  https://ollama.com/sonct988/gemma4-26b-a4b-it-...
# 12      https://ollama.com/maxwellb/gemma4-12b-it-oym
# 13               https://ollama.com/batiai/gemma4-12b
# 14  https://ollama.com/rafw007/gemma4-e4b-claude-c...
# 15               https://ollama.com/Librellama/gemma4
# 16  https://ollama.com/SetneufPT/Gemma4-12B-IT-QAT...
# 17      https://ollama.com/mannix/gemma4-98e-v7-coder
# 18  https://ollama.com/SetneufPT/Gemma4-12B_Q4_64K...
# 19  https://ollama.com/rafw007/gemma4-26b-claude-c...

# %%
df.to_csv(f'{search}_models_list.csv')
